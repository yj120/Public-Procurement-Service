# %%
import pandas as pd

# %%
df_a = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/공사+입찰공고+및+진행+내역(00023)_20220211000138_2017.csv")
# Out:
# C:\Users\yjhon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_b = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/공사+입찰공고+및+진행+내역(00023)_20220211000431_2018.csv")
df_c = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/공사+입찰공고+및+진행+내역(00023)_20220211000716_2019.csv")
df_d = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/공사+입찰공고+및+진행+내역(00023)_20220211001112_2020.csv")
df_e = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/공사+입찰공고+및+진행+내역(00023)_20220211001346_2021.csv")
# Out:
# C:\Users\yjhon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\yjhon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2,3,7,9,18,34,35,37,47,48,52,55,58,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\yjhon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2,3,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_list = [df_a, df_b, df_c, df_d, df_e]
df_all = pd.concat(df_list, ignore_index=True)
df_all
# Out:
#              등록유형  조달구분   공고시스템명             입찰공고번호  입찰공고차수    공고게시일자  \
# 0       나라장터(G2B)  자체조달      NaN        20161235432       1  20170102
# 1       나라장터(G2B)  자체조달      NaN        20161235527       1  20170102
# 2       나라장터(G2B)  자체조달      NaN        20161235722       2  20170102
# 3       나라장터(G2B)  자체조달      NaN        20161236083       0  20170102
# 4       나라장터(G2B)  자체조달      NaN        20161236245       0  20170102
# ...           ...   ...      ...                ...     ...       ...
# 742796  자체전자조달시스템  자체조달  한국수자원공사        B3202103078       1  20210813
# 742797  자체전자조달시스템  자체조달    방위사업청  LPK02292021-27306       2  20211220
# 742798  자체전자조달시스템  자체조달    방위사업청  LFC01192021-21254       1  20211026
# 742799  자체전자조달시스템  자체조달    방위사업청  LPN02832021-26221       1  20211210
# 742800  자체전자조달시스템  자체조달   한국도로공사          202110231       1  20210420
#
#                                 공고명      공사현장  입찰방식 낙찰자결정적용법규  ... 국제입찰여부  \
# ...

# %%
col_name=["등록유형","공고게시일자","조달구분","입찰공고차수","수요기관명","수요기관코드","긴급공고여부","정정공고여부","취소공고여부","추정가격","입찰방식","낙찰자결정방법","입찰계약방법",
"예가방법","업종제한내용","지역제한내용"]

df_corporation = pd.DataFrame(data=df_all,columns = col_name)

# %%
df_corporation['대상'] = '공사'
df_corporation
# Out:
#              등록유형    공고게시일자  조달구분  입찰공고차수              수요기관명   수요기관코드 긴급공고여부  \
# 0       나라장터(G2B)  20170102  자체조달       1    경상남도합천교육청 합천중학교  9220014      Y
# 1       나라장터(G2B)  20170102  자체조달       1            경기도 양주시  5590000      N
# 2       나라장터(G2B)  20170102  자체조달       2  경상북도안동교육청 경안여자중학교  8790030      N
# 3       나라장터(G2B)  20170102  자체조달       0      경기도교육청 광동고등학교  7530542      N
# 4       나라장터(G2B)  20170102  자체조달       0           경상남도 양산시  5380000      Y
# ...           ...       ...   ...     ...                ...      ...    ...
# 742796  자체전자조달시스템  20210813  자체조달       1            한국수자원공사  B500001      N
# 742797  자체전자조달시스템  20211220  자체조달       2              방위사업청  1690000      N
# 742798  자체전자조달시스템  20211026  자체조달       1              방위사업청  1690000      Y
# 742799  자체전자조달시스템  20211210  자체조달       1              방위사업청  1690000      Y
# 742800  자체전자조달시스템  20210420  자체조달       1             한국도로공사  B500004      N
#
# ...

# %%
df_corporation.to_csv('C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/공사_2017_2021.xls', index = False)

# %%
df_aa = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/용역+입찰공고+내역(00027)_20220210225352_2017.csv")
df_bb = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/용역+입찰공고+내역(00027)_20220210225627_2018.csv")
df_cc = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/용역+입찰공고+내역(00027)_20220210231813_2019.csv")
df_dd = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/용역+입찰공고+내역(00027)_20220210232401_2020.csv")
df_ee = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/용역+입찰공고+내역(00027)_20220210232615_2021.csv")
# Out:
# C:\Users\yjhon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\yjhon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\yjhon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,14,15,18,43,44,45,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_list = [df_aa, df_bb, df_cc, df_dd, df_ee]
df_all_service = pd.concat(df_list, ignore_index=True)
df_all_service
# Out:
#              등록유형  용역구분  조달구분   공고시스템명            입찰공고번호  입찰공고차수    공고게시일자  \
# 0       나라장터(G2B)  일반용역  중앙조달      NaN       20170334529       0  20170331
# 1       나라장터(G2B)  일반용역  자체조달      NaN       20170351403       0  20170331
# 2       나라장터(G2B)  일반용역  중앙조달      NaN       20170350664       0  20170331
# 3       나라장터(G2B)  일반용역  자체조달      NaN       20170351391       0  20170331
# 4       나라장터(G2B)  일반용역  자체조달      NaN       20170351388       0  20170331
# ...           ...   ...   ...      ...               ...     ...       ...
# 782345  자체전자조달시스템  일반용역  자체조달  한국수자원공사       B5202104899       0  20211231
# 782346  자체전자조달시스템  일반용역  자체조달  한국수자원공사       B5202104900       0  20211231
# 782347  자체전자조달시스템  일반용역  자체조달  한국수자원공사       B5202104901       0  20211231
# 782348  자체전자조달시스템  일반용역  자체조달    방위사업청  2021MHD009847986       2  20211231
# 782349  자체전자조달시스템  일반용역  자체조달    방위사업청  2021UMM067651432       2  20211231
#
#                                                 공고명        공고기관명  \
# ...

# %%
col_name=["등록유형","공고게시일자","조달구분","입찰공고차수","수요기관명","수요기관코드","긴급공고여부","정정공고여부","취소공고여부","추정가격","입찰방식","낙찰자결정방법","입찰계약방법",
"예가방법","업종제한내용","지역제한내용"]

df_service = pd.DataFrame(data=df_all_service,columns = col_name)

# %%
df_service
# Out:
#              등록유형    공고게시일자  조달구분  입찰공고차수        수요기관명   수요기관코드 긴급공고여부 정정공고여부  \
# 0       나라장터(G2B)  20170331  중앙조달       0        기획재정부  1051000      Y      N
# 1       나라장터(G2B)  20170331  자체조달       0        대림대학교  7008101      Y      N
# 2       나라장터(G2B)  20170331  중앙조달       0    한국대학교육협의회  B340014      Y      N
# 3       나라장터(G2B)  20170331  자체조달       0  (재)경남로봇랜드재단  Z006095      Y      N
# 4       나라장터(G2B)  20170331  자체조달       0     충청남도 예산군  4610000      N      N
# ...           ...       ...   ...     ...          ...      ...    ...    ...
# 782345  자체전자조달시스템  20211231  자체조달       0      한국수자원공사  B500001      N      N
# 782346  자체전자조달시스템  20211231  자체조달       0      한국수자원공사  B500001      N      N
# 782347  자체전자조달시스템  20211231  자체조달       0      한국수자원공사  B500001      N      N
# 782348  자체전자조달시스템  20211231  자체조달       2        방위사업청  1690000      N      N
# 782349  자체전자조달시스템  20211231  자체조달       2        방위사업청  1690000      N      N
#
# ...

# %%
df_service['대상'] = '용역'
df_service
# Out:
#              등록유형    공고게시일자  조달구분  입찰공고차수        수요기관명   수요기관코드 긴급공고여부 정정공고여부  \
# 0       나라장터(G2B)  20170331  중앙조달       0        기획재정부  1051000      Y      N
# 1       나라장터(G2B)  20170331  자체조달       0        대림대학교  7008101      Y      N
# 2       나라장터(G2B)  20170331  중앙조달       0    한국대학교육협의회  B340014      Y      N
# 3       나라장터(G2B)  20170331  자체조달       0  (재)경남로봇랜드재단  Z006095      Y      N
# 4       나라장터(G2B)  20170331  자체조달       0     충청남도 예산군  4610000      N      N
# ...           ...       ...   ...     ...          ...      ...    ...    ...
# 782345  자체전자조달시스템  20211231  자체조달       0      한국수자원공사  B500001      N      N
# 782346  자체전자조달시스템  20211231  자체조달       0      한국수자원공사  B500001      N      N
# 782347  자체전자조달시스템  20211231  자체조달       0      한국수자원공사  B500001      N      N
# 782348  자체전자조달시스템  20211231  자체조달       2        방위사업청  1690000      N      N
# 782349  자체전자조달시스템  20211231  자체조달       2        방위사업청  1690000      N      N
#
# ...

# %%
df_service.to_csv('C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/용역_2017_2021.xls', index = False)

# %%
df_aaa = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/물품+입찰공고+내역(00020)_20220210223734_2017.csv")
df_bbb = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/물품+입찰공고+내역(00020)_20220210223415_2018.csv")
df_ccc = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/물품+입찰공고+내역(00020)_20220210224110_2019.csv")
df_dddd = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/물품+입찰공고+내역(00020)_20220211003757_2020.csv",on_bad_lines='skip')
df_eee = pd.read_csv("C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/물품+입찰공고+내역(00020)_20220210224527_2021.csv")
# Out:
# C:\Users\yjhon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2,3,12,13,14,15,18,35,38,41,42,43,44,45,46,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_list_item = [df_aaa, df_bbb, df_ccc, df_dddd, df_eee]
df_all_item = pd.concat(df_list_item, ignore_index=True)
df_all_item
# Out:
#              등록유형  조달구분   공고시스템명            입찰공고번호  입찰공고차수    공고게시일자  \
# 0       나라장터(G2B)  자체조달      NaN       20170351369       0  20170331
# 1       나라장터(G2B)  자체조달      NaN       20170351360       0  20170331
# 2       나라장터(G2B)  자체조달      NaN       20170351342       0  20170331
# 3       나라장터(G2B)  자체조달      NaN       20170351334       0  20170331
# 4       나라장터(G2B)  자체조달      NaN       20170351337       0  20170331
# ...           ...   ...      ...               ...     ...       ...
# 611667  자체전자조달시스템  자체조달  한국수자원공사       B1202104890       0  20211231
# 611668  자체전자조달시스템  자체조달  한국수자원공사       B1202104892       0  20211231
# 611669  자체전자조달시스템  자체조달  한국수자원공사       B1202104894       2  20211231
# 611670  자체전자조달시스템  자체조달  한국수자원공사       B1202104897       1  20211231
# 611671  자체전자조달시스템  자체조달    방위사업청  2021LKP005660170       1  20211231
#
#                                             공고명                  공고기관명  \
# ...

# %%
col_name=["등록유형","공고게시일자","조달구분","입찰공고차수","수요기관명","수요기관코드","긴급공고여부","정정공고여부","취소공고여부","추정가격","입찰방식","낙찰자결정방법","입찰계약방법",
"예가방법","업종제한내용","지역제한내용"]

df_item = pd.DataFrame(data=df_all_item,columns = col_name)

# %%
df_item['대상'] = '물품'
df_item
# Out:
#              등록유형    공고게시일자  조달구분  입찰공고차수                  수요기관명   수요기관코드  \
# 0       나라장터(G2B)  20170331  자체조달       0  농촌진흥청 국립원예특작과학원 인삼특작부  1390892
# 1       나라장터(G2B)  20170331  자체조달       0                경기도 화성시  5530000
# 2       나라장터(G2B)  20170331  자체조달       0    서울특별시남부교육청 서울도림초등학교  7040064
# 3       나라장터(G2B)  20170331  자체조달       0           충청북도 충주시 앙성면  4390050
# 4       나라장터(G2B)  20170331  자체조달       0            환경부 국립생물자원관  1480592
# ...           ...       ...   ...     ...                    ...      ...
# 611667  자체전자조달시스템  20211231  자체조달       0                한국수자원공사  B500001
# 611668  자체전자조달시스템  20211231  자체조달       0                한국수자원공사  B500001
# 611669  자체전자조달시스템  20211231  자체조달       2                한국수자원공사  B500001
# 611670  자체전자조달시스템  20211231  자체조달       1                한국수자원공사  B500001
# 611671  자체전자조달시스템  20211231  자체조달       1                  방위사업청  1690000
#
#        긴급공고여부 정정공고여부 취소공고여부          추정가격  입찰방식                  낙찰자결정방법  \
# ...

# %%
df_item.to_csv('C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/물품_2017_2021.xls', index = False)

# %%
item = pd.read_csv('C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/물품_2017_2021.xls')
service = pd.read_csv('C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/용역_2017_2021.xls')
corporation = pd.read_csv('C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/공사_2017_2021.xls')

# %%
#item
#service
#corporation

final_total_list = [item, service, corporation]

final_full_dataset = pd.concat(final_total_list, ignore_index=True)

# %%
final_full_dataset.to_csv('C:/Users/yjhon/OneDrive/바탕 화면/조달청_공모전/Regression_timeseries/물품용역공사_2017_2021.xls')
